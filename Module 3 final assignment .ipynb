# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sean Peters**
# Director

# %% [markdown]
# *I am interested in Data Science because of the ubiquitous nature of data*

# %% [markdown]
# ### The following code will print the name of a my favorite cocktail

# %%
print("My favorite cocktail is whiskey ginger")
# Out:
# My favorite cocktail is whiskey ginger

# %% [markdown]
# Here is the recipe for a whiskey ginger.
# ___
# **Ingredients as a bulletted list**
# - 1 1/2 Oz Irish Whiskey
# - 5 Oz Ginger Ale
# - 1 Lime Wedge
#
# **Method as a number list**
# 1. Gather the ingredients
# 2. Pour whiskey into a glass filled with ice
# 3. Fill glass with ginger
# 4. Squeeze lime over drink and drop it in.
# 5. Stir and enjoy!
#
# ### Chef's Notes
# You can use any whiskey including the one hyperlink [Tullamore Dew](https://www.totalwine.com/spirits/irish-whiskey/tullamore-dew-irish-whiskey/p/7658750?s=303&igrules=true&utm_source=pepperjam&utm_medium=affiliate&clickId=4143907264&pid=affiliate%3Apromo%3A%3Apj%3A%3A)
#
# ### Reviews
# > Jimmy says, *"This is the best recipe ever!"
